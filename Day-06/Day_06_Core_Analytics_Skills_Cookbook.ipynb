# %% [markdown]
# # Day 6 – Core Analytics Skills in Practice
# ## Mapping Skills to Real Analysis Using NYC 311 Service Requests Dataset
#
# This notebook demonstrates how core analytics skills create decision value.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
